# %%
s=r'''[  {
   "cell_type": "code",
   "execution_count": 84,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'У этого мальчика есть мяч.'"
      ]
     },
     "execution_count": 84,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('This boy has a ball.')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 85,
   "metadata": {
    "scrolled": false
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'У него нет тетради.'"
      ]
     },
     "execution_count": 85,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('He has no a copy-book.')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 86,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'У него нет его.'"
      ]
     },
     "execution_count": 86,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('He has no him.')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 87,
   "metadata": {
    "scrolled": false
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'Скажите: Доброе утро!'"
      ]
     },
     "execution_count": 87,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('Say: Good morning!')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 148,
   "metadata": {
    "scrolled": true
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'Скажите информацию'"
      ]
     },
     "execution_count": 148,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('Say information')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 159,
   "metadata": {
    "scrolled": false
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'Скажите:\" Семь, шесть, четыре, два, пять, три, один.\"'"
      ]
     },
     "execution_count": 159,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('Say: \"Seven, six, four, two, five, three, one.\"')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 160,
   "metadata": {
    "scrolled": true
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'скажите: скажите семь'"
      ]
     },
     "execution_count": 160,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('say: say seven')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 154,
   "metadata": {
    "scrolled": false
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'Я тоже имею кота.'"
      ]
     },
     "execution_count": 154,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('I have cat too.')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 92,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'У меня нет звезды и у него нет звезды.'"
      ]
     },
     "execution_count": 92,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('I have no star and he has no star.')"
   ]
  }
]
'''

# %%
import json
import re
x="en2ru('I have no star and he has no star.')"
r=re.match(r'^en2ru\((.*)\)$',x)
if r:
    print(r.group(1))
# Out:
# 'I have no star and he has no star.'

# %%
j=json.loads(s)
for cell in j:
    src=cell['source'][0]
    out=cell["outputs"][0]['data']['text/plain'][0]
    r=re.match(r'^en2ru\((.*)\)$',src)
    if r:
        cell['source'][0] = 'ttest(en2ru,'+r.group(1)+','+out+')'
print(json.dumps(j,indent=1))
# Out:
# [
#  {
#   "cell_type": "code",
#   "execution_count": 84,
#   "metadata": {},
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u0423 \u044d\u0442\u043e\u0433\u043e \u043c\u0430\u043b\u044c\u0447\u0438\u043a\u0430 \u0435\u0441\u0442\u044c \u043c\u044f\u0447.'"
#      ]
#     },
#     "execution_count": 84,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'This boy has a ball.','\u0423 \u044d\u0442\u043e\u0433\u043e \u043c\u0430\u043b\u044c\u0447\u0438\u043a\u0430 \u0435\u0441\u0442\u044c \u043c\u044f\u0447.')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 85,
#   "metadata": {
#    "scrolled": false
#   },
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u0423 \u043d\u0435\u0433\u043e \u043d\u0435\u0442 \u0442\u0435\u0442\u0440\u0430\u0434\u0438.'"
#      ]
#     },
#     "execution_count": 85,
#     "metadata": {},
#     "output_type": "execute_result"
# ...

# %%
j[0]["outputs"][0]['data']['text/plain'][0]
# Out:
# "'У этого мальчика есть мяч.'"

# %%
j[0]['source'][0]
# Out:
# "ttest(en2ru,'I have no star and he has no star.','У этого мальчика есть мяч.')"

# %%
j
# Out:
# [{'cell_type': 'code',
#   'execution_count': 84,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'У этого мальчика есть мяч.'"]},
#     'execution_count': 84,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'This boy has a ball.','У этого мальчика есть мяч.')"]},
#  {'cell_type': 'code',
#   'execution_count': 85,
#   'metadata': {'scrolled': False},
#   'outputs': [{'data': {'text/plain': ["'У него нет тетради.'"]},
#     'execution_count': 85,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'He has no a copy-book.','У него нет тетради.')"]},
#  {'cell_type': 'code',
#   'execution_count': 86,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'У него нет его.'"]},
#     'execution_count': 86,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'He has no him.','У него нет его.')"]},
#  {'cell_type': 'code',
# ...
