# %%
s=r'''[    {
   "cell_type": "code",
   "execution_count": 44,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'два мяча'"
      ]
     },
     "execution_count": 44,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('two balls')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 45,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'мальчик видит'"
      ]
     },
     "execution_count": 45,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('boy sees')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 46,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'видь'"
      ]
     },
     "execution_count": 46,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('see')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 47,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'мальчик говорит'"
      ]
     },
     "execution_count": 47,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('boy says')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 48,
   "metadata": {
    "scrolled": false
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'скажи'"
      ]
     },
     "execution_count": 48,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('say')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 49,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'мальчик даёт'"
      ]
     },
     "execution_count": 49,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('boy gives')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 50,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'дай'"
      ]
     },
     "execution_count": 50,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('give')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 51,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'мальчик имеет'"
      ]
     },
     "execution_count": 51,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('boy has')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 52,
   "metadata": {
    "scrolled": false
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'имей'"
      ]
     },
     "execution_count": 52,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('have')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 53,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "'\\nУ этой девочки есть три мяча.'"
      ]
     },
     "execution_count": 53,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "en2ru('\\nThis girl has three balls.')"
   ]
  }

]
'''

# %%
import json
import re
x="en2ru('I have no star and he has no star.')"
r=re.match(r'^en2ru\((.*)\)$',x)
if r:
    print(r.group(1))
# Out:
# 'I have no star and he has no star.'

# %%
j=json.loads(s)
for cell in j:
    src=cell['source'][0]
    out=cell["outputs"][0]['data']['text/plain'][0]
    r=re.match(r'^en2ru\((.*)\)$',src)
    if r:
        cell['source'][0] = 'ttest(en2ru,'+r.group(1)+','+out+')'
print(json.dumps(j,indent=1))
# Out:
# [
#  {
#   "cell_type": "code",
#   "execution_count": 44,
#   "metadata": {},
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u0434\u0432\u0430 \u043c\u044f\u0447\u0430'"
#      ]
#     },
#     "execution_count": 44,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'two balls','\u0434\u0432\u0430 \u043c\u044f\u0447\u0430')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 45,
#   "metadata": {},
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u043c\u0430\u043b\u044c\u0447\u0438\u043a \u0432\u0438\u0434\u0438\u0442'"
#      ]
#     },
#     "execution_count": 45,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'boy sees','\u043c\u0430\u043b\u044c\u0447\u0438\u043a \u0432\u0438\u0434\u0438\u0442')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 46,
#   "metadata": {},
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u0432\u0438\u0434\u044c'"
#      ]
#     },
#     "execution_count": 46,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'see','\u0432\u0438\u0434\u044c')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 47,
#   "metadata": {},
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u043c\u0430\u043b\u044c\u0447\u0438\u043a \u0433\u043e\u0432\u043e\u0440\u0438\u0442'"
#      ]
#     },
#     "execution_count": 47,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'boy says','\u043c\u0430\u043b\u044c\u0447\u0438\u043a \u0433\u043e\u0432\u043e\u0440\u0438\u0442')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 48,
#   "metadata": {
#    "scrolled": false
#   },
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u0441\u043a\u0430\u0436\u0438'"
#      ]
#     },
#     "execution_count": 48,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'say','\u0441\u043a\u0430\u0436\u0438')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 49,
#   "metadata": {},
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u043c\u0430\u043b\u044c\u0447\u0438\u043a \u0434\u0430\u0451\u0442'"
#      ]
#     },
#     "execution_count": 49,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'boy gives','\u043c\u0430\u043b\u044c\u0447\u0438\u043a \u0434\u0430\u0451\u0442')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 50,
#   "metadata": {},
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u0434\u0430\u0439'"
#      ]
#     },
#     "execution_count": 50,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'give','\u0434\u0430\u0439')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 51,
#   "metadata": {},
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u043c\u0430\u043b\u044c\u0447\u0438\u043a \u0438\u043c\u0435\u0435\u0442'"
#      ]
#     },
#     "execution_count": 51,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'boy has','\u043c\u0430\u043b\u044c\u0447\u0438\u043a \u0438\u043c\u0435\u0435\u0442')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 52,
#   "metadata": {
#    "scrolled": false
#   },
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\u0438\u043c\u0435\u0439'"
#      ]
#     },
#     "execution_count": 52,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'have','\u0438\u043c\u0435\u0439')"
#   ]
#  },
#  {
#   "cell_type": "code",
#   "execution_count": 53,
#   "metadata": {},
#   "outputs": [
#    {
#     "data": {
#      "text/plain": [
#       "'\\n\u0423 \u044d\u0442\u043e\u0439 \u0434\u0435\u0432\u043e\u0447\u043a\u0438 \u0435\u0441\u0442\u044c \u0442\u0440\u0438 \u043c\u044f\u0447\u0430.'"
#      ]
#     },
#     "execution_count": 53,
#     "metadata": {},
#     "output_type": "execute_result"
#    }
#   ],
#   "source": [
#    "ttest(en2ru,'\\nThis girl has three balls.','\\n\u0423 \u044d\u0442\u043e\u0439 \u0434\u0435\u0432\u043e\u0447\u043a\u0438 \u0435\u0441\u0442\u044c \u0442\u0440\u0438 \u043c\u044f\u0447\u0430.')"
#   ]
#  }
# ]

# %%
j[0]["outputs"][0]['data']['text/plain'][0]
# Out:
# "'два мяча'"

# %%
j[0]['source'][0]
# Out:
# "ttest(en2ru,'two balls','два мяча')"

# %%
j
# Out:
# [{'cell_type': 'code',
#   'execution_count': 44,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'два мяча'"]},
#     'execution_count': 44,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'two balls','два мяча')"]},
#  {'cell_type': 'code',
#   'execution_count': 45,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'мальчик видит'"]},
#     'execution_count': 45,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'boy sees','мальчик видит')"]},
#  {'cell_type': 'code',
#   'execution_count': 46,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'видь'"]},
#     'execution_count': 46,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'see','видь')"]},
#  {'cell_type': 'code',
#   'execution_count': 47,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'мальчик говорит'"]},
#     'execution_count': 47,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'boy says','мальчик говорит')"]},
#  {'cell_type': 'code',
#   'execution_count': 48,
#   'metadata': {'scrolled': False},
#   'outputs': [{'data': {'text/plain': ["'скажи'"]},
#     'execution_count': 48,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'say','скажи')"]},
#  {'cell_type': 'code',
#   'execution_count': 49,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'мальчик даёт'"]},
#     'execution_count': 49,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'boy gives','мальчик даёт')"]},
#  {'cell_type': 'code',
#   'execution_count': 50,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'дай'"]},
#     'execution_count': 50,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'give','дай')"]},
#  {'cell_type': 'code',
#   'execution_count': 51,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'мальчик имеет'"]},
#     'execution_count': 51,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'boy has','мальчик имеет')"]},
#  {'cell_type': 'code',
#   'execution_count': 52,
#   'metadata': {'scrolled': False},
#   'outputs': [{'data': {'text/plain': ["'имей'"]},
#     'execution_count': 52,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'have','имей')"]},
#  {'cell_type': 'code',
#   'execution_count': 53,
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["'\\nУ этой девочки есть три мяча.'"]},
#     'execution_count': 53,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["ttest(en2ru,'\\nThis girl has three balls.','\\nУ этой девочки есть три мяча.')"]}]
